# %% [markdown]
# # 1.	1.	Fill in the table of 2016 sales by month by store using only 1 SUMIFS Formula (Many Sales Sample Data)

# %% [markdown]
# # SOLUTION
# =SUMIFS($C$2:$C$150000,$B$2:$B$150000,$E16,$A$2:$A$150000,F$15)

# %% [markdown]
# # OUTPUT
# ![34.PNG](attachment:34.PNG)

# %% [markdown]
# # 2.	Fill in the table of 2016 sales by month by store using only 1 SUMPRODUCT Formula (Many Sales Sample Data)

# %% [markdown]
# # SOLUTION
# =SUMPRODUCT(($C$2:$C$150000)*($B$2:$B$150000=$E3)*($A$2:$A$150000=F$2))

# %% [markdown]
# # OUTPUT
# ![35.PNG](attachment:35.PNG)

# %% [markdown]
# # 3.	Create a Pivot Table that only shows the 2016 sales by month by store. (Many Sales Sample Data)

# %% [markdown]
# # SOLUTION

# %% [markdown]
# click on Insert.....>then on pivot table;Filter the rows and columns depending on the requirement

# %% [markdown]
# # OUTPUT

# %% [markdown]
# ![36.PNG](attachment:36.PNG)
