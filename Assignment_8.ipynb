# %% [markdown]
# # The Challenge before you is to write a formula to clean the data. If you perform any mathematical operation on the data, it will return #VALUE error. You need to clean the data through a formula. (Problem-Workbook)

# %% [markdown]
# ![22.PNG](attachment:22.PNG)

# %% [markdown]
# ![23.PNG](attachment:23.PNG)

# %% [markdown]
# # IF OPERATIONS ARE PERFORMED ON A COLUMN ERROR IS SHOWN AS ABOVE

# %% [markdown]
# # SOLUTION:

# %% [markdown]
# # =--SUBSTITUTE(SUBSTITUTE(A2,LEFT(A2,1),""),RIGHT(A2,1),"")

# %% [markdown]
# # OUTPUT
# ![24.PNG](attachment:24.PNG)

# %% [markdown]
# # PERFORM MATHEMEATICAL OPERATION ON B COLUMN
