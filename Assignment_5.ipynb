# %% [markdown]
# # 1.	Write a formula which can be dragged right and down to generate a multiplication table. (Generate Multiplication Table.xlsx)

# %% [markdown]
# ![18.PNG](attachment:18.PNG)

# %% [markdown]
# # Solution

# %% [markdown]
# # =$A2 * B$1
# # NOW FROM THIS CELL DRAG DOWN AND RIGHT

# %% [markdown]
# # OUTPUT

# %% [markdown]
# ![19.PNG](attachment:19.PNG)
