# %% [markdown]
# # Find duplicates and show the count

# %% [markdown]
# ![14.PNG](attachment:14.PNG)

# %% [markdown]
# # Solution

# %% [markdown]
# ![15.PNG](attachment:15.PNG)

# %% [markdown]
# # =COUNTIF($A$2:$A$19,E2);
# # Click on enter
# # Drag the cell down till panel room

# %% [markdown]
# ![16.PNG](attachment:16.PNG)
