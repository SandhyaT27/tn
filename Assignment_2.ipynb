# %% [markdown]
# # EXERCISE 1

# %% [markdown]
# # Fill the blank values using countif-sumif

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # QUESTION:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Solution:

# %% [markdown]
# # Number of orders in Boston                 :  =COUNTIF(G2:G25,"Boston")
# # Number of microwave orders               :  =COUNTIF(D2:D25,"microwave")
# # Number of journeys with truck 3          :  =COUNTIF(F2:F25,"truck 3")
# # Number of Peter white journeys           :  =COUNTIF(C2:C25,"Peter White")
# # How many times are no. of items < 20 :  =COUNTIF(E2:E25,"<20")

# %% [markdown]
# # OUTPUT:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # QUESTION:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # SOLUTION:

# %% [markdown]
# # sum of refrigerator items:  = SUMIF(D2:D25,"refrigerator",E2:E25)
# # sum of washing machine items:=SUMIF(D2:D25,"washing machine",E2:E25)
# # sum of items transported by truck 4:=SUMIF(F2:F25,"truck 4",E2:E25)
# # sum of items transported by trucks:=SUMIF(F2:F25,"TRUCK*",E2:E25)

# %% [markdown]
# # OUTPUT:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # QUESTION:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # SOLUTION:

# %% [markdown]
# # number of microvawe orders in Boston:
# # =COUNTIFS(D2:D25,"microwave",G2:G25,"Boston")
# # number of Peter White journeys with truck 1:
# # =COUNTIFS(C2:C25,"Peter White",F2:F25,"truck 1")
# # number of orders in Boston after 2/3/2013:
# # =COUNTIFS(G2:G25,"Boston",B2:B25,">02/03/2013")
# # number of orders between 2/3/2013 and 2/6/2013:
# # =COUNTIFS(B2:B25,">=02/03/2013",B2:B25,"<=02/06/2013")

# %% [markdown]
# # OUTPUT

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # QUESTION:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # SOLUTION:

# %% [markdown]
# # sum of microwaves transported to NY:
# # = SUMIFS(E2:E25,D2:D25,"microwave",G2:G25,"NY")
# # sum of items transported to Pittsburgh by truck 1:
# # = SUMIFS(E2:E25,F2:F25,"truck 1",G2:G25,"Pittsburgh")
# # sum of items ordered between 2/3/2013 and 2/6/2013:
# # = SUMIFS(E2:E25,B2:B25,">=02/03/2013",B2:B25,"02/06/2013")
#
#
# # sum of items transported to NY, Baltimore and Philadelphia:
# # =SUMIF(G2:G25,"NY","E2:E25")+SUMIF(G2:G25,"Baltimore",E2:E25)+
# #   SUMIF(G2:G25,"Philadelphia",E2:E25)

# %% [markdown]
# # OUTPUT

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # EXERCISE 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # How many times total

# %% [markdown]
# # Shaving:
# # =COUNTIF(B16:B241,"Shaving")
# # Washing and combing:
# # =COUNTIF(B16:B241,"Washing and combing")
# # Dyeing:
# # =COUNTIF(B16:B241,"Dyeing")
# # Meeting hairstyles:
# # =COUNTIF(B16:B241,"Meeting hairstyles")

# %% [markdown]
# # Total Price:

# %% [markdown]
# # Shaving:
# # =SUMIF(B16:B241,"Shaving",E16:E241)
# # Washing and combing:
# #  =SUMIF(B16:B241,"Washing and combing",E16:E241)
# # Dyeing:
# #  =SUMIF(B16:B241,"Dyeing",E16:E241)
# # Meeting hairstyles:
# #  =SUMIF(B16:B241,"Meeting hairstyles",E16:E241)

# %% [markdown]
# # How many times by cash

# %% [markdown]
# # Shaving

# %% [markdown]
# # =COUNTIFS(B16:B241,"Shaving",D16:D241,"cash")

# %% [markdown]
# # Washing and combing

# %% [markdown]
# # =COUNTIFS(B16:B241,"Washing and combing",D16:D241,"cash")

# %% [markdown]
# # Dyeing

# %% [markdown]
# # =COUNTIFS(B16:B241,"Dyeing",D16:D241,"cash")

# %% [markdown]
# # Meeting hairstyles

# %% [markdown]
# # =COUNTIFS(B16:B241,"Meeting hairstyles",D16:D241,"cash")

# %% [markdown]
# # How  many times by credit card:

# %% [markdown]
# # Shaving:

# %% [markdown]
# # =COUNTIFS(B16:B241,"Shaving",D16:D241,"credit card")

# %% [markdown]
# # Washing and combing

# %% [markdown]
# # =COUNTIFS(B16:B241,"Washing and combing",D16:D241,"credit card")

# %% [markdown]
# # Dyeing

# %% [markdown]
# # =COUNTIFS(B16:B241,"Dyeing",D16:D241,"credit card")

# %% [markdown]
# # Meeting hairstyles

# %% [markdown]
# # =COUNTIFS(B16:B241,"Meeting hairstyles",D16:D241,"credit card")

# %% [markdown]
# # Total price by cash

# %% [markdown]
# # Shaving

# %% [markdown]
# # = SUMIFS(E16:E241,D16:D241,"cash",B16:B241,"Shaving")

# %% [markdown]
# # Washing and combing

# %% [markdown]
# # = SUMIFS(E16:E241,D16:D241,"cash",B16:B241,"Washing and combing")

# %% [markdown]
# # Dyeing

# %% [markdown]
# # = SUMIFS(E16:E241,D16:D241,"cash",B16:B241,"Dyeing")

# %% [markdown]
# # Meeting hairstyles

# %% [markdown]
# # = SUMIFS(E16:E241,D16:D241,"cash",B16:B241,"Meeting hairstyles")

# %% [markdown]
# # HOW MANY TIMES TOTAL

# %% [markdown]
# # Jane

# %% [markdown]
# # =COUNTIF(C16:C241,"Jane")

# %% [markdown]
# # Martha

# %% [markdown]
# # =COUNTIF(C16:C241,"Martha")

# %% [markdown]
# # Alex

# %% [markdown]
# # =COUNTIF(C16:C241,"Alex")

# %% [markdown]
# # Total Price

# %% [markdown]
# # Jane

# %% [markdown]
# # =SUMIF(C16:C241,"Jane",E16:E241)

# %% [markdown]
# # Martha

# %% [markdown]
#  # =SUMIF(C16:C241,"Martha",E16:E241)

# %% [markdown]
# # Alex

# %% [markdown]
#  # =SUMIF(C16:C241,"Alex",E16:E241)

# %% [markdown]
# # How many times shaving

# %% [markdown]
# # Jane

# %% [markdown]
# # =COUNTIFS(B16:B241,"Shaving",C16:C241,"Jane")

# %% [markdown]
# # Martha

# %% [markdown]
# # =COUNTIFS(B16:B241,"Shaving",C16:C241,"Martha")

# %% [markdown]
# # Alex

# %% [markdown]
# # =COUNTIFS(B16:B241,"Shaving",C16:C241,"Alex")

# %% [markdown]
# # How many times kids

# %% [markdown]
# # Jane

# %% [markdown]
# # =COUNTIFS(B16:B241,"Kids",C16:C241,"Jane")

# %% [markdown]
# # Martha

# %% [markdown]
# # =COUNTIFS(B16:B241,"Kids",C16:C241,"Martha")

# %% [markdown]
# # Alex

# %% [markdown]
# # =COUNTIFS(B16:B241,"Kids",C16:C241,"Alex")
